# %% [markdown]
# POCZĄTEK

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/version/__init__.py'>

# %% [markdown]
# DRUGI BLOK KODU

# %%
observations = 1000
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(low=-10, high=10, size=(observations,1))
inputs=np.column_stack((xs,zs))
print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# TRZECI BLOK KODU

# %%
noise = np.random.uniform(low=-1, high=1, size=(observations,1))
targets = 2 * xs - 3 * zs + 5 + noise
np.savez('TF_dataset', inputs=inputs, targets=targets)
print(targets.shape)
# Out:
# (1000, 1000)

# %% [markdown]
# CZWARTY BLOK KODU

# %%
targets=targets.reshape(observations,)
xs=xs.reshape(observations,)
zs=zs.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('targets')
ax.view_init(azim=100)
plt.show()

# %% [markdown]
# PIĄTY BLOK KODU

# %%
init_range=0.1
weights=np.random.uniform(low=-init_range,high=init_range,size=(2,1))
biases=np.random.uniform(low=-init_range,high=init_range,size=(1,))
print(weights,biases)
# Out:
# [[-0.00819852]
#  [-0.06244637]] [0.01955342]

# %% [markdown]
# SZÓSTY BLOK KODU

# %%
targets = targets.reshape(observations,1)
eta = 0.02
for i in range(100):
  outputs = np.dot(inputs,weights) + biases
  deltas = outputs - targets
  loss = np.sum(deltas ** 2) / 2 / observations
  print(loss)
  deltas_scaled = deltas / observations
  weights = weights - eta * np.dot(inputs.T,deltas_scaled)
  biases = biases - eta * np.sum(deltas_scaled)
print(weights,biases)
# Out:
# 0.38771090678168657
# 0.37914953353062836
# 0.37092473315369373
# 0.3630232739769118
# 0.3554324445025053
# 0.3481400329592244
# 0.3411343076566247
# 0.334403998111669
# 0.32793827691730354
# 0.32172674232383197
# 0.31575940150506565
# 0.31002665448233524
# 0.304519278680492
# 0.2992284140910617
# 0.29414554901867573
# 0.28926250638785717
# 0.28457143058812095
# 0.28006477483623826
# 0.2757352890353218
# 0.2715760081112112
# 0.2675802408073887
# 0.2637415589203958
# 0.26005378695844195
# 0.2565109922065625
# 0.25310747518234467
# 0.2498377604668657
# 0.24669658789609683
# 0.2436789040985956
# 0.24077985436588
# 0.2379947748423999
# 0.2353191850225449
# 0.2327487805426152
# 0.23027942625616493
# 0.2279071495815706
# 0.22562813411112767
# 0.22343871347139338
# 0.22133536542489504
# 0.21931470620372068
# 0.2173734850658711
# 0.21550857906561907
# 0.21371698802945813
# 0.21199582972956646
# 0.2103423352470122
# 0.20875384451724602
# 0.20722780205071495
# 0.2057617528217093
# 0.20435333831883254
# 0.20300029275073883
# 0.2017004394010332
# 0.20045168712647296
# 0.19925202699283345
# 0.19809952904302947
# 0.19699233919228987
# 0.19592867624539348
# 0.19490682903116477
# 0.19392515364962257
# 0.19298207082734992
# 0.19207606337683383
# 0.191205673755684
# 0.19036950172180744
# 0.18956620208076438
# 0.18879448252168254
# 0.18805310153824742
# 0.18734086643142558
# 0.18665663139070593
# 0.18599929565077322
# 0.1853678017206491
# 0.18476113368244895
# 0.18417831555702208
# 0.18361840973384086
# 0.18308051546261747
# 0.18256376740421906
# 0.18206733423854995
# 0.18159041732716405
# 0.18113224942845113
# 0.1806920934633357
# 0.18026924132949795
# 0.17986301276221206
# 0.17947275423996847
# 0.17909783793311831
# 0.1787376606938515
# 0.17839164308587954
# 0.1780592284522666
# 0.1777398820199055
# 0.17743309003919927
# 0.17713835895756574
# 0.1768552146254325
# 0.17658320153344778
# 0.17632188207967778
# 0.17607083586561367
# 0.1758296590198539
# 0.1755979635483747
# 0.17537537671034362
# 0.1751615404184717
# 0.1749561106629388
# 0.17475875695796725
# 0.1745691618101515
# 0.17438702020768995
# 0.17421203912969563
# 0.17404393707479857
# [[ 1.99797784]
#  [-3.00144086]] [4.9060459]

# %% [markdown]
# SIÓDMY BLOK KODU

# %%
plt.plot(outputs, targets, color = 'orange')
plt.xlabel('Outputs')
plt.ylabel('Targets')
plt.title('Outputs vs Targets')
plt.show()

# %% [markdown]
# NOWY KOD - ĆWICZENIA

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
observations = 100000
xs = np.random.uniform(low=-10, high=10, size=(observations, 1))
zs = np.random.uniform(low=-10, high=10, size=(observations, 1))
inputs = np.column_stack((xs, zs))
print(inputs.shape)
# Out:
# (100000, 2)

# %%
noise = np.random.uniform(low=-1, high=1, size=(observations, 1))
targets = 13 * xs + 7 * zs - 12 + noise
np.savez('TF_dataset', inputs=inputs, targets=targets)
print(targets.shape)
# Out:
# (100000, 1)

# %%
targets = targets.reshape(observations,)
xs = xs.reshape(observations,)
zs = zs.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('targets')
ax.view_init(azim=100)
plt.show()

# %%
init_range = 0.1
weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))
biases = np.random.uniform(low=-init_range, high=init_range, size=(1,))
print(weights, biases)
# Out:
# [[-0.01188614]
#  [ 0.05533104]] [-0.02244219]

# %%
targets = targets.reshape(observations,1)
eta_values = [0.0001, 0.001, 0.01, 0.05]

for eta in eta_values:
    print(f"Testing for eta = {eta}")

    targets = targets.reshape(observations, 1)

    for i in range(100):
        outputs = np.dot(inputs, weights) + biases
        deltas = outputs - targets
        loss = np.sum(deltas ** 2) / 2 / observations
        print(f"Epoch {i+1}, Loss: {loss}")
        deltas_scaled = deltas / observations
        weights = weights - eta * np.dot(inputs.T, deltas_scaled)
        biases = biases - eta * np.sum(deltas_scaled)
# Out:
# Testing for eta = 0.0001
# Epoch 1, Loss: 3694.407466318213
# Epoch 2, Loss: 3670.3219603307484
# Epoch 3, Loss: 3646.396406543757
# Epoch 4, Loss: 3622.6297420992046
# Epoch 5, Loss: 3599.020911201825
# Epoch 6, Loss: 3575.5688650721954
# Epoch 7, Loss: 3552.272561900103
# Epoch 8, Loss: 3529.1309667982437
# Epoch 9, Loss: 3506.14305175621
# Epoch 10, Loss: 3483.3077955948006
# Epoch 11, Loss: 3460.6241839206155
# Epoch 12, Loss: 3438.091209080975
# Epoch 13, Loss: 3415.7078701191163
# Epoch 14, Loss: 3393.473172729704
# Epoch 15, Loss: 3371.386129214629
# Epoch 16, Loss: 3349.4457584390975
# Epoch 17, Loss: 3327.651085788024
# Epoch 18, Loss: 3306.001143122702
# Epoch 19, Loss: 3284.494968737768
# Epoch 20, Loss: 3263.1316073184503
# Epoch 21, Loss: 3241.9101098981055
# Epoch 22, Loss: 3220.8295338160265
# Epoch 23, Loss: 3199.8889426755504
# Epoch 30, Loss: 0.5601794701918144
# Epoch 31, Loss: 0.5218409519738463
# Epoch 32, Loss: 0.4872404043483321
# Epoch 33, Loss: 0.4560133785885208
# Epoch 34, Loss: 0.4278309593864353
# Epoch 35, Loss: 0.40239630037692453
# Epoch 36, Loss: 0.379441497444952
# Epoch 37, Loss: 0.3587247668825855
# Epoch 38, Loss: 0.34002789867310385
# Epoch 39, Loss: 0.32315395807758784
# Epoch 40, Loss: 0.3079252113147123
# Epoch 41, Loss: 0.2941812534848884
# Epoch 42, Loss: 0.28177731902007025
# Epoch 43, Loss: 0.2705827568631911
# Epoch 44, Loss: 0.2604796543161973
# Epoch 45, Loss: 0.25136159506165645
# Epoch 46, Loss: 0.24313253827612055
# Epoch 47, Loss: 0.2357058070289125
# Epoch 48, Loss: 0.22900317531112085
# Epoch 49, Loss: 0.22295404407842048
# Epoch 50, Loss: 0.21749469762898022
# Epoch 51, Loss: 0.21256763248384158
# Epoch 52, Loss: 0.2081209517008464
# Epoch 53, Loss: 0.20410781824240673
# Epoch 54, Loss: 0.2004859616394252
# Epoch 55, Loss: 0.19721723275502248
# Epoch 56, Loss: 0.19426720195840633
# Epoch 57, Loss: 0.1916047964764113
# Epoch 58, Loss: 0.18920197310294562
# Epoch 59, Loss: 0.18703342281895644
# Epoch 60, Loss: 0.18507630421168753
# Epoch 61, Loss: 0.1833100028853148
# Epoch 62, Loss: 0.1817159143288207
# Epoch 63, Loss: 0.1802772479540622
# Epoch 64, Loss: 0.17897885023993979
# Epoch 65, Loss: 0.17780704511985304
# Epoch 66, Loss: 0.17674948993123357
# Epoch 67, Loss: 0.1757950454098675
# Epoch 68, Loss: 0.17493365835965152
# Epoch 69, Loss: 0.1741562557619415
# Epoch 70, Loss: 0.17345464920914375
# Epoch 71, Loss: 0.17282144865594493
# Epoch 72, Loss: 0.17224998457971513
# Epoch 73, Loss: 0.17173423773020333
# Epoch 74, Loss: 0.1712687757285741
# Epoch 75, Loss: 0.17084869584797782
# Epoch 76, Loss: 0.17046957337296542
# Epoch 77, Loss: 0.17012741499381304
# Epoch 78, Loss: 0.16981861674485557
# Epoch 79, Loss: 0.16953992604379678
# Epoch 80, Loss: 0.16928840743215
# Epoch 81, Loss: 0.16906141165595673
# Epoch 82, Loss: 0.16885654776110537
# Epoch 83, Loss: 0.16867165790933142
# Epoch 84, Loss: 0.16850479464963497
# Epoch 85, Loss: 0.16835420040571433
# Epoch 86, Loss: 0.16821828896335542
# Epoch 87, Loss: 0.16809562876278492
# Epoch 88, Loss: 0.167984927820003
# Epoch 89, Loss: 0.1678850201182722
# Epoch 90, Loss: 0.16779485332642496
# Epoch 91, Loss: 0.16771347771462353
# Epoch 92, Loss: 0.16764003615082387
# Epoch 93, Loss: 0.1675737550725751
# Epoch 94, Loss: 0.16751393633906078
# Epoch 95, Loss: 0.16745994987755763
# Epoch 96, Loss: 0.16741122704685898
# Epoch 97, Loss: 0.1673672546477576
# Epoch 98, Loss: 0.1673275695175012
# Epoch 99, Loss: 0.16729175365128393
# Epoch 100, Loss: 0.16725942979938768

# %%
    plt.plot(outputs, targets, color='orange')
    plt.xlabel('Outputs')
    plt.ylabel('Targets')
    plt.title(f'Outputs vs Targets (eta = {eta})')
    plt.show()
